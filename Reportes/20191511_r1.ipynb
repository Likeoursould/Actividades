# %%
# %matplotlib widget
# %matplotlib inline
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
from sympy import *
import pandas as pd

# %% [markdown]
#                                                         REPORTE 1

# %% [markdown]
# Nombre: Claudia Zevallos
#
# Codigo: 20191511

# %% [markdown]
# CONTROL DE LECTURA
# ------

# %% [markdown]
# El  artículo “Las vacas flacas de la economía peruana” del economista e investigador Oscar Dancourt muestra un panorama de las políticas fiscales entre el 2014 y 2015, junto a su crítica y las consecuencuancias que produjo, es por ello que se plantea la siguiente pregunta sería ¿Cuáles fueron las políticas fiscales peruanas ante el shock recesivo del 2014-2015?
# Las fortalezas presentes en la lectura “Las vacas flacas de la economía peruana” pueden ser, en primer lugar, que hacen uso de la data oficial del Banco Central de Reserva (BCR), por lo cual, entra a una veracidad de análisis, cuenta con explicaciones necesarias y fáciles para entender  y cuenta con formulas económicas-matemáticas para sustentar las explicaciones de las dificultades económicas en el caso peruano, además, desde un análisis en cuanto al contenido , vemos, por una parte que el autor en un excelente conocedor de la materia económica discutida en el artículo ya que Oscar Dancourt ha sido ex director del Banco Central de Reserva del Perú en el periodo de gobierno de Alejandro Toledo; por otra parte, el texto presenta una división de temáticas bastante consisa, pasando de definición tanto de shock e inflación terminado con una explicación de la reseción peruana en el 2014-2015 concluyendo con las conclusiones y recomendación de gobierno.
# Por otro lado, las debilidades del texto presentan es que no contempla la acción privada, si bien tiene un enfoque total en cuanto a las acciones de entidades públicas, en especial el Banco Central de Reserva, no posee una mirada en cuanto al sector privado que es importante para la circulación económica. Asimismo, no tanto como una debilidad, sino como una recomendación, sería mas objetivo usar las más objetivo usar las fórmulas económicas para explicar el shock recesivo y las acciones del BCR por reducir el impacto negativa de dicha crisis a lo largo del texto en vez de dejarlo en la parte final.
# Dicho artículo contribuye   a la búsqueda de la solución para manejar posibles choques económicos negativos, puesto que brinda recomendaciones secuenciales y concretas. Además, nos brinda un panorama amplio de las causas y  de lo sucedido durante el periodo de recesión en la economía peruana junto a ser un trabajo calificado para el área.
# Quizás, un tema adicional a discusión y para avanzar en la pregunta sería

# %% [markdown]
# CÓDIGO
# ---

# %% [markdown]
# 1. Derive y explique la función de demanda de Consumo. Replique el gráfico siguiente:

# %% [markdown]
# Para hallar el Gasto de consumo familiar empezamos por la tributación total de la econmoía representado en $$𝑇 = 𝑡𝑌$$ donde $$(0 < t < 1)$$
#
# Y donde la t es la tasa impositiva que en Perú sería más conocido como IGV
# $$𝑌^𝑑 = 𝑌 − 𝑇 𝑌𝑑 = 1𝑌 − 𝑡𝑌$$
# $$𝑌^𝑑 = (1 − 𝑡)𝑌$$
#
# Enronces la función de consumo sería usando la formula anterior con la proporcion marginal
# $$𝐂 = 𝐂𝟎 + 𝐛𝑌^𝑑$$
#
# Recordemos que 𝑑𝐶/𝑑𝑌𝑑 = 𝑏 , donde (0 < 𝑏 < 1) Para poder encontrar la b
# $$𝐂 = 𝐂𝟎 + b(1 − 𝑡)𝑌 𝐂 = 𝐂𝟎 + ∆𝐶/∆𝑌^𝑑(1 − 𝑡)𝑌$$
#
# b= 𝑑𝐶/𝑑𝑌𝑑=PMgC B es igual a la diferencia de consumo con la diferencia de ingreso disponible Además
#
# $$𝐂 = 𝐂𝟎 + 𝐛𝑌𝑑 𝐂/𝑌𝑑 = 𝐂𝟎/𝑌𝑑 + 𝐛*𝑌𝑑/𝑌𝑑 𝐶/𝑌𝑑 = 𝐶0/𝑌𝑑 + b$$
#
# Además es interesante resaltar que PMgC y PMeC coincide solo cunado el consumo autónomo (Co) es igual a 0

# %%
Y_size = 100 

Co = 35
b = 0.8
t = 0.3

Y = np.arange(Y_size)


def C(Co, b, t, Y):
    C = Co + b*(1-t)*Y
    return C

C = C(Co, b, t, Y)

# %%
y_max = np.max(C)
fig, ax = plt.subplots(figsize=(10, 8))

custom_xlim = (0, 130)
custom_ylim = (20, 130)

plt.setp(ax, xlim=custom_xlim, ylim=custom_ylim)


ax.plot(Y, C, label = "Consumo", color = "#960D0D") 

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())


plt.text(80, 95, '$PMgC = △C/△Y^d = b = 0.5$', fontsize = 13, color = 'black')


ax.set(title="Función de demanda de Consumo", xlabel= '$Y^d$', ylabel= 'C')
ax.legend() 

plt.show()

# %% [markdown]
# 2. Derive y explique la función de Inversión. Replique el gráfico siguiente:

# %% [markdown]
# Entendemos ccon que la inversión es la cantidad que, pensando en la unidad familiar, invierte una familia y esta tiene las siguientes parte:
#
# I = Inversion Io= Inversión autónomo no cambia
#
# h= sensibilidad de los inversionista, en donde (0<h<1)
#
# r= la tasa de interés
#
# A raíz de ello, se forja la siguiente formula:
#
# $$I = Io − hr I + hr= Io$$
#
# Por otro lado, es importante mencionar el lo tan variable que es la tasa de interés que ha terminos de negocios o inversiones internacionales juega un valor importante, puesto que se relaciona con la inversión de manera inversamente proporciales, pensado que a mayor tasa de interés, menor es la inversión conseguida.
#
# $$I↓ = r↑$$

# %%
# Parámetros

Io = 40
h = 0.7

r = np.arange(start = 0.01, stop = 1, step =0.01)  
r

# Ecuación de la curva del ingreso de equilibrio

def I(Io, h, r):
    I = Io - h*r
    return I

I = I(Io, h, r)

# %%
# Gráfico

# Dimensiones del gráfico
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

custom_xlim = (0.1, 1.25)
custom_ylim = (39.1, 40.2)

plt.setp(ax, xlim=custom_xlim, ylim=custom_ylim)


# Curvas a graficar
ax.plot(r, I, label = "Inversión", color = "#0AED6E") #Demanda agregada

# Eliminar las cantidades de los ejes
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

# Texto agregado
    # punto de equilibrio
plt.text(0.8, 39.5, '$I = Io - hr$', fontsize = 12.5, color = 'black')


# Título y leyenda
ax.set(title="Función de demanda de Inversión", xlabel= 'r', ylabel= 'I')
ax.legend() #mostrar leyenda

plt.show()

# %% [markdown]
# 3. ¿Cuáles son los supuestos del modelo Ingreso-Gasto Keynesiano?

# %% [markdown]
# 1) Es un modelo de corto plazo.
#
# 2) El nivel de precios es rígido o fijo.
#
# 3) El nivel del producción $(Y)$ se adapta a los cambios de la Demanda Agregada $(DA)$.
#
# 4) La tasa de interés $(r)$ se determina afuera del modelo de Ingreso-Gasto. Se da en el mercado monetario $(LM)$.

# %% [markdown]
# 4. A partir de las siguientes ecuaciones

# %% [markdown]
# Encuentre el nivel de Ingreso de equilibrio

# %% [markdown]
# Entendemos al modelo Ingreso-Gasto Keynesiano como un gráfico que expone un punto de encuentro entre la Demanda Agregada (DA) y el Ingreso agregrada (Y) que necesita la economía para estar en equilibrio, entendiendo a una fórmula:
#
# $$DA=Y$$
#
# Antes de analizar el punto de equilibrio, es importante denominar variables:
#
# Consumo: C = Co + bYd
#
# Inversión: I = Io − hr
#
# Gasto del Gobierno: G = Go
#
# Tributación: T = tY
#
# Exportaciones: X = Xo
#
# Importaciones: M = mYd
#
# La Demanada Agregada significa la suma de todo lo anterior
#
# Demanda Agregada:
#
# $$DA = C + I + G + X − M$$
#
# Además sabemos que
#                   $$Y^d=(1+t)$$
#
# Reemplazamos
#
#
# $$DA=Co+bYd+Io-hr+Go+tY+Xo+mYd$$
# $$Da=Co+Io+Go+Xo-hr+Y(b-m)(1-t)$$
#
# Para encontrar la pendiente que nos dará el equilibrio debemos sintetizar la anterior formular, en donde:
# $$𝐷𝐴 = 𝛼0 + 𝛼1𝑌$$
#
# Nuestro intercepto estará determinada por : $$𝛼0= (C0 + I0 + G0 + X0 − hr)$$
# Nuestra pendiente estará determinada por:   $$𝛼1= (b − m)(1 − t)$$
#
# Ahora, considerando el equilibrio entre $$Y=DA$$, el punto de equilibrio estaría conformado:
#
# $$ Y^e = C_0 + bY^d + I_0 -hr + G_0 + X_0 - mY^d $$
#
# $$ Y^e = \frac{1}{1 - (b - m)(1 - t)} (C_0 + I_0 + G_0 + X_0 - hr) $$
#
# Donde el multiplicador keynesiano es:
#
# $$k= \frac{1}{1 - (b - m)(1 - t)}$$

# %%
Replique el siguiente gráfico con todas descripciones encima de las rectas.

# %%
# Parámetros

Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8 # b > m
m = 0.2
t = 0.3
r = 0.9

Y = np.arange(Y_size)



def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_IS_K = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
#Recta de 45·
a= 2.5
def L_45(a, Y):
    L_45 = a*Y
    return L_45

L_45 = L_45(a, Y)

# %%
y_max = np.max(DA_IS_K)
fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(DA_IS_K, label = "DA", color = "#4995E0")
ax.plot(L_45, color = "#062A03") 

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())


plt.axvline(x=70.5,  ymin= 0, ymax= 0.69, linestyle = ":", color = "grey")
plt.axhline(y=176, xmin= 0, xmax= 0.7, linestyle = ":", color = "grey")

plt.axvline(x=70.5,  ymin= 0, ymax= 0.69, linestyle = ":", color = "grey")
plt.axhline(y=145, xmin= 0, xmax= 1, linestyle = ":", color = "grey")

plt.text(0, 180, '$DA^e$', fontsize = 11.5, color = 'black')
plt.text(72, 0, '$Y^e$', fontsize = 12, color = 'black')
plt.text(0, 152, '$α_o$', fontsize = 15, color = 'black')

plt.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
plt.text(2.5, -3, '$◝$', fontsize = 30, color = '#404040')
  
plt.text(87, 203, '$DA = α_0 + α_1 Y$', fontsize = 11.5, color = '#3D59AB')
plt.text(80, 165, '$α_1 = (b-m)(1-t)$', fontsize = 11.5, color = 'black')
plt.text(73, 125, '$α_0 = C_o + I_o + G_o + X_o - hr$', fontsize = 11.5, color = 'black')

plt.text(92, 192, '$↓$', fontsize = 13, color = 'black')
plt.text(85, 135, '$↑$', fontsize = 13, color = 'black')


ax.set(title="El ingreso de Equilibrio", xlabel= r'Y', ylabel= r'DA')
ax.legend()

plt.show()

# %% [markdown]
# 5. Estática comparativa en el modelo de Ingreso-Gasto keynesiano

# %% [markdown]
# Analice una Política Fiscal Expansiva con aumento del Gasto del Gobierno . El análisis debe ser intuitivo, matemático y gráfico.

# %% [markdown]
# Intuición:

# %% [markdown]
# $$ ↑Go → ↑DA → DA > Y → ↑Y $$

# %% [markdown]
# - Matemáticamente: $∆G_0 > 0  →  ¿∆Y?$

# %% [markdown]
# $$Y = \frac{1}{1 - (b - m)(1 - t)} (C_0 + I_0 + G_0 + X_0 - hr)$$
#
# Considerando el multiplicador keynesiano $(k)$:
#
# $$ Y = k (C_0 + I_0 + G_0 + X_0 - hr) $$
# $$ ∆Y = k (∆C_0 + ∆I_0 + ∆G_0 + ∆X_0 - ∆hr) $$
#
# Entonces:
#
# $$∆C_0 = ∆I_0 = ∆X_0 = ∆h = ∆r = 0$$
#
# $$ ∆Y = k (∆G_0) $$
#
# Simplificando:
#
# $$ ∆Y = (+)(+) $$
# $$ ∆Y > 0 $$

# %% [markdown]
# Esto también se puede ver en diferenciales

# %%
Co, Io, Go, Xo, h, r, b, m, t = symbols('Co Io Go Xo h r b m t')

f = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))


df_Go = diff(f, Go) 
df_Go #∆Y/∆Go
# Out:
# 1/(-(1 - t)*(b - m) + 1)

# %% [markdown]
# La pendiente es representada por el diferencial de $ ∆Go/∆Y $: $ \frac{1}{-(1-t)(b-m)+1} $ y es positivo

# %%
#Graficamos
Y_size = 100 

Co = 35
Io = 40
Go = 30
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3
r = 0.9

Y = np.arange(Y_size)

    # Ecuación 
def ejer5(Co, Io, Go, Xo, h, r, b, m, t, Y):
    ejer5= (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return ejer5

ejercicio5= ejer5(Co, Io, Go, Xo, h, r, b, m, t, Y)

#--------------
Go = 70
def ejer5(Co, Io, Go, Xo, h, r, b, m, t, Y):
    ejer5 = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return ejer5

ejercicio6= ejer5(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
y_max = np.max(ejercicio5)
fig, ax = plt.subplots(figsize=(10, 8))


ax.plot(Y, ejercicio5, label = "DA", color = "#D249E0") 
ax.plot(Y, ejercicio6, label = "DA_G", color = "#E04995", linestyle = 'dashed') 
ax.plot(Y, L_45, color = "#404040")


plt.axvline(x = 70.5, ymin= 0, ymax = 0.69, linestyle = ":", color = "grey")
plt.axhline(y = 176, xmin= 0, xmax = 0.7, linestyle = ":", color = "grey")
plt.axvline(x = 51,  ymin= 0, ymax = 0.52, linestyle = ":", color = "grey")
plt.axhline(y = 128, xmin= 0, xmax = 0.52, linestyle = ":", color = "grey")


plt.text(0, 180, '$DA^e$', fontsize = 11.5, color = 'black')
plt.text(0, 125, '$DA_G$', fontsize = 11.5, color = '#EE7600')
plt.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
plt.text(2.5, -3, '$◝$', fontsize = 30, color = '#404040')
plt.text(72, 0, '$Y^e$', fontsize = 12, color = 'black')
plt.text(56, 0, '$Y_G$', fontsize = 12, color = '#EE7600')
plt.text(60, 45, '$←$', fontsize = 18, color = 'grey')
plt.text(20, 140, '$↓$', fontsize = 18, color = 'grey')

ax.set(title = "Política fiscal de reducción del Gasto del Gobierno $(G_0)$", xlabel = r'Y', ylabel = r'DA')
ax.legend()

plt.show()

# %% [markdown]
# Analice una Pol í t ica f iscal expansiva con una reducción de la Tasa de Tributación . El análisis debe ser intuitivo, matemático y gráfico.

# %%
INTUICIÓN

# %% [markdown]
# $$ t↓ → Co↑ → DA↑ → DA > Y → Y↑ $$
# $$ t↓ → M↑ → DA↓ → DA < Y → Y↓ $$

# %%
Matemática

# %%
Co, Io, Go, Xo, h, r, b, m, t = symbols('Co Io Go Xo h r b m t')

f = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))


df_t = diff(f, t)
df_t #∆Y/∆t
# Out:
# (-b + m)*(Co + Go + Io + Xo - h*r)/(-(1 - t)*(b - m) + 1)**2

# %% [markdown]
# La pendiente es representada por el diferencial de $ ∆Go/∆Y $: $ \frac{(-b+m)(Co+Go+Io+Xo-hr)}{(-(1-t)(b-m)+1)^2} $ y es positivo

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3 
r = 0.9

Y = np.arange(Y_size)

 
def ejer7(Co, Io, Go, Xo, h, r, b, m, t, Y):
    ejer7= (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return ejer7

ejercicio7 = ejer7(Co, Io, Go, Xo, h, r, b, m, t, Y)


#--------------------------------------------------

t = 0.025


def ejer7(Co, Io, Go, Xo, h, r, b, m, t, Y):
    ejer7 = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return ejer7

ejercicio8 = ejer7(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
y_max = np.max(ejercicio7)
fig, ax = plt.subplots(figsize=(10, 8))


ax.plot(Y, ejercicio7, label = "DA", color = "#008080") 
ax.plot(Y, ejercicio8, label = "DA_t", color = "#CD5C5C", linestyle = 'dashed') #NUEVA curva
ax.plot(Y, L_45, color = "#404040") 

plt.axvline(x = 70.5, ymin= 0, ymax = 0.69, linestyle = ":", color = "grey")
plt.axhline(y = 176, xmin= 0, xmax = 0.7, linestyle = ":", color = "grey")
plt.axvline(x = 77,  ymin= 0, ymax = 0.75, linestyle = ":", color = "grey")
plt.axhline(y = 192, xmin= 0, xmax = 0.75, linestyle = ":", color = "grey")


plt.text(0, 180, '$DA^e$', fontsize = 11.5, color = 'black')
plt.text(0, 200, '$DA_t$', fontsize = 11.5, color = '#CD5C5C')
plt.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
plt.text(2.5, -3, '$◝$', fontsize = 30, color = '#404040')
plt.text(72, 0, '$Y^e$', fontsize = 12, color = 'black')
plt.text(80, 0, '$Y_t$', fontsize = 12, color = '#CD5C5C')
plt.text(72, 45, '$→$', fontsize = 18, color = 'grey')
plt.text(20, 180, '$↑$', fontsize = 18, color = 'grey')

ax.set(title = "Política fiscal de reducción de la Tasa de Tributación", xlabel = r'Y', ylabel = r'DA')
ax.legend()

plt.show()

# %% [markdown]
# 6. Estática comparativa en el modelo de Ingreso-Gasto keynesiano con Regla Contracíclica.
# Ahora vamos a utilizar un modelo con regla contracíclica. Este tipo de política fiscal hace que los auges y las depresiones no sean muy pronunciados. Se establece como una regla consistente en una variación del Gasto (G) (La magnitud es exactamente igual que en 5) en sentido contrario a la variación del Producto, Y. Uilice las siguientes ecuaciones y responda.

# %% [markdown]
# Grafique la Funcion de demanda Agregada y la recta de 45 grados señalando los valores de intercepto y pendiente como en el apartado (4).

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
g = 0.2
Xo = 2
h = 0.7
b = 0.8 
m = 0.2
t = 0.3
r = 0.9

Y = np.arange(Y_size)



def DA_C(Co, Io, Go, Xo, h, r, b, m, t, g, Y):
    DA_C = (Co  + Io + Go + Xo - h*r) + [(b-m)*(1-t)-g]*Y
    return DA_C

DA_Cont = DA_C(Co, Io, Go, Xo, h, r, b, m, t, g, Y)

# %%
y_max = np.max(DA_Cont)
fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(DA_Cont, label = "DA", color = "#AEE049") 
ax.plot(L_45, color = "#404040") 

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())


plt.axvline(x=64,  ymin= 0, ymax= 0.63, linestyle = ":", color = "grey")
plt.axhline(y=161, xmin= 0, xmax= 0.63, linestyle = ":", color = "grey")
plt.axhline(y=145, xmin= 0, xmax= 1, linestyle = ":", color = "grey")


plt.text(0, 165, '$DA^e$', fontsize = 11.5, color = 'black')
plt.text(65, 0, '$Y^e$', fontsize = 12, color = 'black')
plt.text(0, 135, '$α_o$', fontsize = 15, color = 'black')
    
plt.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
plt.text(2.5, -3, '$◝$', fontsize = 30, color = '#404040')

plt.text(82, 185, '$DA = α_0 + α_1 Y$', fontsize = 11.5, color = '#AEE049')
plt.text(75, 151, '$α_1 = [(b-m)(1-t)-g]$', fontsize = 11.5, color = 'black')
plt.text(73, 125, '$α_0 = C_o + I_o + G_o + X_o - hr$', fontsize = 11.5, color = 'black')

plt.text(87, 175, '$↓$', fontsize = 13, color = 'black')
plt.text(85, 135, '$↑$', fontsize = 13, color = 'black')

ax.set(title="El ingreso de Equilibrio con regla contracíclica", xlabel= r'Y', ylabel= r'DA')
ax.legend()

plt.show()

# %% [markdown]
# Encuentre el nivel de Ingreso de equilibrio

# %% [markdown]
# Entendemos al modelo Ingreso-Gasto Keynesiano como un gráfico que expone un punto de encuentro entre la Demanda Agregada (DA) y el Ingreso agregrada (Y) que necesita la economía para estar en equilibrio, entendiendo a una fórmula:
#
# $$DA=Y$$
#
# Antes de analizar el punto de equilibrio, es importante denominar variables:
#
# Consumo: C = Co + bYd
#
# Inversión: I = Io − hr
#
# Gasto del Gobierno: G = Go
#
# Tributación: T = tY
#
# Exportaciones: X = Xo
#
# Importaciones: M = mYd
#
# La Demanada Agregada significa la suma de todo lo anterior
#
# Demanda Agregada:
#
# $$DA = C + I + G + X − M$$
#
# $$ DA = α_0 + α_1Y $$
#
# Donde $ α_0 = (C_0 + I_0 + G_0 + X_0 -hr)$ es el intercepto y $ α_1 = [(b - m)(1 - t) - g] $ es la pendiente de la función
#
# Ahora, considerando la condición de equilibrio $Y = DA$, la ecuación del ingreso de equilibrio a corto plazo es:
#
# $$ Y^e = \frac{1}{1 - (b - m)(1 - t) + g} (C_0 + I_0 + G_0 + X_0 - hr) $$

# %% [markdown]
# Analice una Política Fiscal Expansiva con aumento del Gasto del Gobierno . El análisis debe ser intuitivo, matemático y gráfico.

# %% [markdown]
# Intuición

# %% [markdown]
# $$ ↑Go → ↑DA → DA > Y → ↑Y $$

# %% [markdown]
# Matemática:

# %%
Co, Io, Go, Xo, h, r, b, m, t, g = symbols('Co Io Go Xo h r b m t g')

f = (Co + Io + Go + Xo - h*r)/(1 - (b - m)*(1 - t) + g)

df_Go = diff(f, Go) 
df_Go #∆Y/∆Go
# Out:
# 1/(g - (1 - t)*(b - m) + 1)

# %% [markdown]
# La pendiente es representada por el diferencial de $ ∆Go/∆Y $: $ \frac{1}{g-(1-t)(b-m)+1} $ y es positivo

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3
r = 0.9
g = 0.2

Y = np.arange(Y_size)


def DA_C(Co, Io, Go, Xo, h, r, b, m, t, g, Y):
    DA_C = (Co  + Io + Go + Xo - h*r) + [(b-m)*(1-t)-g]*Y
    return DA_C

DA_Cont = DA_C(Co, Io, Go, Xo, h, r, b, m, t, g, Y)


Go = 100

def DA_C(Co, Io, Go, Xo, h, r, b, m, t, g, Y):
    DA_C = (Co  + Io + Go + Xo - h*r) + [(b-m)*(1-t)-g]*Y
    return DA_C

DA_C_G = DA_C(Co, Io, Go, Xo, h, r, b, m, t, g, Y)

# %%
def line_intersection(line1, line2):
    xdiff = (line1[0][0] - line1[1][0], line2[0][0] - line2[1][0])
    ydiff = (line1[0][1] - line1[1][1], line2[0][1] - line2[1][1])

    def det(a, b):
        return a[0] * b[1] - a[1] * b[0]

    div = det(xdiff, ydiff)
    if div == 0:
       raise Exception('lines do not intersect')

    d = (det(*line1), det(*line2))
    x = det(d, xdiff) / div
    y = det(d, ydiff) / div
    return x, y

 
A = [DA_Cont[0], Y[0]] 
B = [DA_Cont[-1], Y[-1]]

C = [L_45[0], Y[0]] 
D = [L_45[-1], Y[-1]] 



intersec = line_intersection((A, B), (C, D))
intersec
# Out:
# (160.4934210526316, 64.19736842105264)

# %%
   
A = [DA_C_G[0], Y[0]] 
B = [DA_C_G[-1], Y[-1]] 

C = [L_45[0], Y[0]] 
D = [L_45[-1], Y[-1]] 


intersec_G = line_intersection((A, B), (C, D))
intersec_G
# Out:
# (193.38815789473685, 77.35526315789474)

# %%
# Gráfico
y_max = np.max(DA_Cont)
fig, ax = plt.subplots(figsize=(10, 8))


ax.plot(DA_Cont, label = "DA", color = "#386266")
ax.plot(DA_C_G, label = "DA_G", color = "#B6E12E", linestyle = 'dashed') 
ax.plot(L_45, color = "#404040") 

plt.axhline(y=intersec[0], xmin= 0, xmax= 0.64, linestyle = ":", color = "grey")
plt.axvline(x=intersec[1], ymin= 0, ymax= 0.64, linestyle = ":", color = "grey")

plt.axhline(y=intersec_G[0], xmin= 0, xmax= 0.76, linestyle = ":", color = "grey")
plt.axvline(x=intersec_G[1], ymin= 0, ymax= 0.76, linestyle = ":", color = "grey")


plt.text(0, 135, '$DA^e$', fontsize = 11.5, color = 'black')
plt.text(0, 182, '$DA_G$', fontsize = 11.5, color = '#EE7600')
plt.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
plt.text(2.5, -3, '$◝$', fontsize = 30, color = '#404040')
plt.text(60, 0, '$Y^e$', fontsize = 12, color = 'black')
plt.text(72, 0, '$Y_G$', fontsize = 12, color = '#EE7600')
plt.text(70, 45, '$→$', fontsize = 18, color = 'grey')
plt.text(20, 165, '$↑$', fontsize = 18, color = 'grey')


ax.set(title = "Incremento del Gasto del Gobierno $(G_0)$", xlabel = r'Y', ylabel = r'DA')
ax.legend()

plt.show()

# %% [markdown]
# ¿Cuál es el papel que juega el parametro  en el multiplicador keynesiano?

# %% [markdown]
# El parámetro $g$ dentro de la regla contracíclica dentro del denominador en nuestro multiplicador Keynesiano, este va afectar al aumento del denominador de la formula, por lo que su reacción va a ser inversamente proporcial. Al ocurrir esto, disminuye el multiplicador y la curve de la Demanda Agregada se reduce.

# %% [markdown]
# El tamaño del efecto de la politica fiscal encontrado en 6 es el mismo que en el apartado 5 ?

# %% [markdown]
# El tamañaño del efecto de la política fiscal del ejercicio 5  y 6 son diferentes, ya que el efecto 6 es mejor al ejercicio 5. Los motivos detras son que en el ejercio 5
#
#
# No, el tamaño del efecto de la política fiscal del ejercicio 6) es menor al efecto del ejercicio 5).  Esto se debe a que el valor del multiplicador keynesiano $(k)$ se ha reducido por la adición de $g$ en el denominador. Entonces, si $k$ es más pequeño, el impacto de una política fiscal expansiva $(∆G_0)$ será menor cuando se utilice la regla contracíclica (la adición de $g$). De allí que la pendiente de la curva de la Demanda Agregada $(DA)$ sea menor en el apartado 6).

# %% [markdown]
# Analice una crisis mundial que reduce nuestras exportaciones . El análisis debe ser intuitivo, matemático y gráfico

# %% [markdown]
# Intuición:

# %% [markdown]
# $$ ↓Xo → ↓DA → DA < Y → ↓Y $$

# %% [markdown]
# Matemática:

# %%
Co, Io, Go, Xo, h, r, b, m, t, g = symbols('Co Io Go Xo h r b m t g')

f = (Co + Io + Go + Xo - h*r)/(1 - (b - m)*(1 - t) + g)

df_Xo = diff(f, Xo)
df_Xo
# Out:
# 1/(g - (1 - t)*(b - m) + 1)

# %% [markdown]
# La pendiente es representada por el diferencial de $ ∆Xo/∆Y $: $ \frac{1}{g-(1-t)(b-m)+1} $ y es negativo

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
g = 0.2 
Xo = 15
h = 0.7
b = 0.8 
m = 0.2
t = 0.3
r = 0.9

Y = np.arange(Y_size)


def DA_C(Co, Io, Go, Xo, h, r, b, m, t, g, Y):
    DA_C = (Co  + Io + Go + Xo - h*r) + [(b-m)*(1-t)-g]*Y
    return DA_C

DA_Cont = DA_C(Co, Io, Go, Xo, h, r, b, m, t, g, Y)


Xo = 1

def DA_C(Co, Io, Go, Xo, h, r, b, m, t, g, Y):
    DA_C = (Co  + Io + Go + Xo - h*r) + [(b-m)*(1-t)-g]*Y
    return DA_C

DA_C_X = DA_C(Co, Io, Go, Xo, h, r, b, m, t, g, Y)

# %%
def line_intersection(line1, line2):
    xdiff = (line1[0][0] - line1[1][0], line2[0][0] - line2[1][0])
    ydiff = (line1[0][1] - line1[1][1], line2[0][1] - line2[1][1])

    def det(a, b):
        return a[0] * b[1] - a[1] * b[0]

    div = det(xdiff, ydiff)
    if div == 0:
       raise Exception('lines do not intersect')

    d = (det(*line1), det(*line2))
    x = det(d, xdiff) / div
    y = det(d, ydiff) / div
    return x, y

   
A = [DA_Cont[0], Y[0]]
B = [DA_Cont[-1], Y[-1]] 

C = [L_45[0], Y[0]] 
D = [L_45[-1], Y[-1]] 

   
intersec = line_intersection((A, B), (C, D))
intersec
# Out:
# (174.7478070175439, 69.89912280701755)

# %%
  
A = [DA_C_X[0], Y[0]] 
B = [DA_C_X[-1], Y[-1]] 

C = [L_45[0], Y[0]] 
D = [L_45[-1], Y[-1]] 

intersec_X = line_intersection((A, B), (C, D))
intersec_X
# Out:
# (159.39692982456143, 63.75877192982457)

# %%
y_max = np.max(DA_Cont)
fig, ax = plt.subplots(figsize=(10, 8))


ax.plot(DA_Cont, label = "DA", color = "#683CCD") 
ax.plot(DA_C_X, label = "DA_X", color = "#101EA5", linestyle = 'dashed') 
ax.plot(L_45, color = "#404040") 

plt.axhline(y=intersec[0], xmin= 0, xmax= 0.68, linestyle = ":", color = "grey")
plt.axvline(x=intersec[1], ymin= 0, ymax= 0.68, linestyle = ":", color = "grey")

plt.axhline(y=intersec_X[0], xmin= 0, xmax= 0.63, linestyle = ":", color = "grey")
plt.axvline(x=intersec_X[1], ymin= 0, ymax= 0.63, linestyle = ":", color = "grey")


plt.text(0, 180, '$DA^e$', fontsize = 11.5, color = 'black')
plt.text(0, 135, '$DA_X$', fontsize = 11.5, color = '#EE7600')
plt.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
plt.text(2.5, -3, '$◝$', fontsize = 30, color = '#404040')
plt.text(71, 0, '$Y^e$', fontsize = 12, color = 'black')
plt.text(60, 0, '$Y_X$', fontsize = 12, color = '#EE7600')
plt.text(65.5, 45, '$←$', fontsize = 15, color = 'grey')
plt.text(20, 165, '$↓$', fontsize = 15, color = 'grey')


ax.set(title = "Reducción de las Exportaciones", xlabel = r'Y', ylabel = r'DA')
ax.legend()

plt.show()
